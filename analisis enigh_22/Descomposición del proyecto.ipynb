# %% [markdown]
# # Plan de Proyecto: Análisis ENIGH 2022 (Educación y Becas)
#
# Este documento detalla las etapas de desarrollo para el análisis de datos de la Encuesta Nacional de Ingresos y Gastos de los Hogares (ENIGH) 2022, enfocado en educación básica y el programa de Becas Benito Juárez.
#
# ## 📅 Fase 1: Configuración y Adquisición de Datos (Setup)
# - [ ] **Configuración del Entorno**
#     - [ ] Crear repositorio en GitHub `analisis-enigh-2022`.
#     - [ ] Crear entorno virtual (`venv` o `conda`).
#     - [ ] Instalar dependencias (`pandas`, `matplotlib`, `seaborn`).
#     - [ ] Crear archivo `.gitignore` (Importante: excluir archivos CSV grandes y carpetas de entorno).
# - [ ] **Adquisición de Datos**
#     - [ ] Descargar microdatos `poblacion.csv` y `ingresos.csv` del sitio de INEGI.
#     - [ ] Descargar "Descripción de la Base de Datos" (PDF) para diccionario de variables.
#     - [ ] Validar integridad de los archivos (verificar que carguen las primeras filas).
#
# ## 🧹 Fase 2: Preprocesamiento y Limpieza (ETL)
# - [ ] **Exploración Inicial (EDA)**
#     - [ ] Identificar columnas clave para llaves primarias (`folioviv`, `foliohog`, `numren`).
#     - [ ] Mapeo de catálogo de Entidades Federativas (01 = Aguascalientes, etc.).
# - [ ] **Filtrado y Limpieza**
#     - [ ] Filtrar `df_poblacion` para rango de edad 6-12 años (Parte 1).
#     - [ ] Filtrar `df_poblacion` para personas que asisten a la escuela (Parte 2).
#     - [ ] Identificar códigos de ingresos para "Becas Benito Juárez" en `df_ingresos` (Consultar PDF, claves tipo `P102`, `P107`, etc.).
# - [ ] **Fusión de Datos (Merge)**
#     - [ ] Realizar `left join` entre tabla Población y tabla Ingresos usando las 3 llaves compuestas.
#     - [ ] Crear columna booleana `tiene_beca`.
#
# ## 📊 Fase 3: Análisis y Resolución de Preguntas
# ### Parte 1: Educación Básica (6-12 años)
# - [ ] **Cálculo de Indicadores**
#     - [ ] Calcular % de asistencia escolar.
#     - [ ] Calcular % de hablantes monolingües de lengua indígena.
#     - [ ] Calcular % de población con discapacidad (validar columnas `disver`, `disoir`, etc.).
# - [ ] **Visualización 1**
#     - [ ] Generar Gráfica de Barras: Distribución por grado escolar.
#     - [ ] Añadir títulos, etiquetas y paleta de colores accesible.
#
# ### Parte 2: Becas Benito Juárez
# - [ ] **Cálculo de Indicadores**
#     - [ ] Calcular % de mujeres beneficiarias vs. total de mujeres estudiantes.
#     - [ ] Agrupar beneficiarios por Entidad Federativa.
#     - [ ] Identificar estados con mayor y menor cobertura (Max/Min).
# - [ ] **Visualización 2**
#     - [ ] Generar Histograma/Pirámide: Distribución por Edad y Sexo de beneficiarios.
#     - [ ] Asegurar legibilidad de la leyenda.
# - [ ] **Interpretación**
#     - [ ] Redactar hallazgos basados en los datos (p.ej. correlación con regiones, enfoque de edad).
#
# ## 🚀 Fase 4: Documentación y Entrega
# - [ ] **Refactorización**
#     - [ ] Limpiar celdas de código innecesarias en el Jupyter Notebook.
#     - [ ] Añadir comentarios explicativos en el código (`docstrings`).
# - [ ] **README Principal**
#     - [ ] Redactar descripción del proyecto.
#     - [ ] Incluir instrucciones de instalación (`pip install -r requirements.txt`).
#     - [ ] Insertar imágenes de las gráficas generadas.
#     - [ ] Añadir sección de "Conclusiones/Hallazgos".
# - [ ] **Publicación**
#     - [ ] Push final a GitHub.
#     - [ ] (Opcional) Publicar notebook renderizado en nbviewer o Kaggle.
